# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Connect to the SQLite database file
conn = sqlite3.connect("sales_data.db")

# %%
# Run SQL query to calculate total quantity and revenue per product
query = '''
SELECT 
    product,
    SUM(quantity) AS total_qty,
    SUM(quantity * price) AS revenue
FROM 
    sales
GROUP BY 
    product
'''

# %%
# Execute the query and load results into a DataFrame
df = pd.read_sql_query(query, conn)

# %%
# Print the sales summary
print("📦 Sales Summary:")
print(df)
# Out:
# 📦 Sales Summary:
#       product  total_qty   revenue
# 0    Keyboard         30   21000.0
# 1      Laptop         10  600000.0
# 2     Monitor         12  144000.0
# 3  Smartphone         25  500000.0
# 4      Tablet         15  225000.0

# %%
# Plot revenue by product
df.plot(kind='bar', x='product', y='revenue', color='skyblue', title='Revenue by Product')
plt.ylabel("Revenue (INR)")
plt.tight_layout()
plt.savefig("sales_chart.png")  # Save chart as PNG
plt.show()

# Close the database connection
conn.close()
